# %% [markdown]
# <a href="https://colab.research.google.com/github/davismaulana/2023/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
# We will load dataset only for faces with contain min 10 images
# We also want to keep images in color; color=True
faces = fetch_lfw_people(min_faces_per_person=10, color=True)

# Check Faces
print(f'Total Label: {len(faces.target_names)}')
print(f'Data dimension: {faces.images.shape}')
print(f'Images flatten dimension: {faces.data.shape}')
# Out:
# Total Label: 158
# Data dimension: (4324, 62, 47, 3)
# Images flatten dimension: (4324, 8742)

# %%
# Check by Plotted Images
# Generate random 15 images
rand_labels = [np.random.randint(0, len(faces.data)) for x in range(0,15)]

fig, ax = plt.subplots(3, 5)
fig.tight_layout()
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[rand_labels[i]], cmap='bone')
    axi.set(xticks=[], yticks=[],
            xlabel=faces.target_names[faces.target[rand_labels[i]]])

# %%
# Function Extract Histogram Features For Each Channel
def generate_hist(data, bins_num=5):
    hist_data = []

    for i in data:
        h_red = np.histogram(i[0][..., 0].ravel(), bins=bins_num)[0]
        h_green = np.histogram(i[1][..., 1].ravel(), bins=bins_num)[0]
        h_blue = np.histogram(i[2][..., 2].ravel(), bins=bins_num)[0]

        h_concat = np.concatenate((h_red, h_green, h_blue), axis=0) # Concat in row basis

        hist_data.append(h_concat)

    return np.array(hist_data)

# %%
# Extract histogram feature
hist_features = generate_hist(faces.images, bins_num=50)
hist_features.shape
# Out:
# (4324, 150)

# %%
# Build a Model
X_train, X_test, y_train, y_test = train_test_split(hist_features, faces.target, test_size=0.2, random_state=42, stratify=faces.target)

model = SVC()

model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Evaluation
# Eval on Training
y_train_predict = model.predict(X_train)
acc_train = accuracy_score(y_train, y_train_predict)

# Eval on Test
y_test_predict = model.predict(X_test)
acc_test = accuracy_score(y_test, y_test_predict)

# Print
print(f'Accuracy on Train: {acc_train:.2%}')
print(f'Accuracy on Test: {acc_test:.2%}')
# Out:
# Accuracy on Train: 23.27%
# Accuracy on Test: 13.64%

# %%
# Eval Classification Report
print(classification_report(y_test, y_test_predict, target_names=faces.target_names))
# Out:
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.00      0.00      0.00         4
#              Adrien Brody       0.00      0.00      0.00         2
#          Alejandro Toledo       0.00      0.00      0.00         8
#              Alvaro Uribe       0.00      0.00      0.00         7
#           Amelie Mauresmo       0.00      0.00      0.00         4
#              Andre Agassi       0.00      0.00      0.00         7
#              Andy Roddick       0.00      0.00      0.00         3
#            Angelina Jolie       0.00      0.00      0.00         4
#               Ann Veneman       0.00      0.00      0.00         2
#           Anna Kournikova       0.00      0.00      0.00         2
#             Ari Fleischer       0.00      0.00      0.00         3
#              Ariel Sharon       0.00      0.00      0.00        16
#     Arnold Schwarzenegger       0.00      0.00      0.00         8
#      Atal Bihari Vajpayee       0.00      0.00      0.00         5
#              Bill Clinton       0.00      0.00      0.00         6
#                Bill Gates       0.00      0.00      0.00         3
#              Bill McBride       0.00      0.00      0.00         2
#                Bill Simon       0.00      0.00      0.00         3
#            Britney Spears       0.00      0.00      0.00         3
#              Carlos Menem       0.00      0.00      0.00         4
#               Carlos Moya       0.00      0.00      0.00         4
#      Catherine Zeta-Jones       0.00      0.00      0.00         2
#             Charles Moose       0.00      0.00      0.00         3
#              Colin Powell       0.07      0.11      0.08        47
#          Condoleezza Rice       0.00      0.00      0.00         2
#             David Beckham       0.00      0.00      0.00         6
#          David Nalbandian       0.00      0.00      0.00         3
#          Mahathir Mohamad       0.00      0.00      0.00         3
#             Mahmoud Abbas       0.00      0.00      0.00         6
#        Mark Philippoussis       0.00      0.00      0.00         2
#     Megawati Sukarnoputri       0.00      0.00      0.00         7
#              Meryl Streep       0.00      0.00      0.00         3
#         Michael Bloomberg       0.00      0.00      0.00         4
#           Michael Jackson       0.00      0.00      0.00         2
#        Michael Schumacher       0.00      0.00      0.00         4
#                 Mike Weir       0.00      0.00      0.00         2
#          Mohammad Khatami       0.00      0.00      0.00         2
#         Mohammed Al-Douri       0.00      0.00      0.00         3
#              Muhammad Ali       0.00      0.00      0.00         2
#              Nancy Pelosi       0.00      0.00      0.00         3
#               Naomi Watts       0.00      0.00      0.00         4
#           Nestor Kirchner       0.00      0.00      0.00         7
#     Nicanor Duarte Frutos       0.00      0.00      0.00         2
#             Nicole Kidman       0.00      0.00      0.00         4
#               Norah Jones       0.00      0.00      0.00         3
#       Paradorn Srichaphan       0.00      0.00      0.00         2
#               Paul Bremer       0.00      0.00      0.00         4
#              Paul Burrell       0.00      0.00      0.00         2
#            Paul Wolfowitz       0.00      0.00      0.00         2
#          Pervez Musharraf       0.00      0.00      0.00         4
#              Pete Sampras       0.00      0.00      0.00         4
#            Pierce Brosnan       0.00      0.00      0.00         3
#        Queen Elizabeth II       0.00      0.00      0.00         3
#      Recep Tayyip Erdogan       0.00      0.00      0.00         6
#           Renee Zellweger       0.00      0.00      0.00         3
#             Ricardo Lagos       0.00      0.00      0.00         5
#          Richard Gephardt       0.00      0.00      0.00         2
#              Richard Gere       0.00      0.00      0.00         2
#             Richard Myers       0.00      0.00      0.00         4
#             Roger Federer       0.00      0.00      0.00         3
#              Roh Moo-hyun       0.00      0.00      0.00         6
#        Rubens Barrichello       0.00      0.00      0.00         2
#          Rudolph Giuliani       0.00      0.00      0.00         5
#            Saddam Hussein       0.00      0.00      0.00         5
#               Salma Hayek       0.00      0.00      0.00         3
#           Serena Williams       0.00      0.00      0.00        11
#             Sergey Lavrov       0.00      0.00      0.00         2
#    Sergio Vieira De Mello       0.00      0.00      0.00         2
#         Silvio Berlusconi       0.00      0.00      0.00         7
#           Spencer Abraham       0.00      0.00      0.00         3
#       Taha Yassin Ramadan       0.00      0.00      0.00         3
#              Tang Jiaxuan       0.00      0.00      0.00         2
#               Tiger Woods       0.00      0.00      0.00         5
#                Tim Henman       0.00      0.00      0.00         4
#                Tom Cruise       0.00      0.00      0.00         2
#               Tom Daschle       0.00      0.00      0.00         5
#                 Tom Hanks       0.00      0.00      0.00         2
#                 Tom Ridge       0.00      0.00      0.00         7
#              Tommy Franks       0.00      0.00      0.00         3
#            Tommy Thompson       0.00      0.00      0.00         2
#                Tony Blair       0.00      0.00      0.00        29
#                Trent Lott       0.00      0.00      0.00         3
#            Venus Williams       0.00      0.00      0.00         3
#               Vicente Fox       0.00      0.00      0.00         6
#            Vladimir Putin       0.00      0.00      0.00        10
#            Walter Mondale       0.00      0.00      0.00         2
#                Wen Jiabao       0.00      0.00      0.00         3
#              Winona Ryder       0.00      0.00      0.00         5
#          Yoriko Kawaguchi       0.00      0.00      0.00         3
#
#                  accuracy                           0.14       865
#                 macro avg       0.00      0.01      0.01       865
#              weighted avg       0.03      0.14      0.04       865
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Eval Confusion Matrix
# This is too large, we may not want it
mat = confusion_matrix(y_test, y_test_predict)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=faces.target_names,
            yticklabels=faces.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(113.92222222222219, 0.5, 'predicted label')
